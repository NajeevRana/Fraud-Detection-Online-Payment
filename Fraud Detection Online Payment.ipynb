# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv ('C:/Users/Anika!!/Desktop/Data Analyst/Online Payment Fraud Detection/archive/onlinefraud.csv')

# %%
## Return first 5 rows of the dataframe
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
## number of rows and columns of a given dataframes
df.shape
# Out:
# (6362620, 11)

# %%
##print information about the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
##return the description of data in the dataframe
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# 50%      1.327057e+05    2.146614e+05  0.000000e+00    0.000000e+00
# 75%      9.430367e+05    1.111909e+06  0.000000e+00    0.000000e+00
# max      3.560159e+08    3.561793e+08  1.000000e+00    1.000000e+00

# %%
##checking for missing value
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.iloc[0,:]
# Out:
# step                        1
# type                  PAYMENT
# amount                9839.64
# nameOrig          C1231006815
# oldbalanceOrg        170136.0
# newbalanceOrig      160296.36
# nameDest          M1979787155
# oldbalanceDest            0.0
# newbalanceDest            0.0
# isFraud                     0
# isFlaggedFraud              0
# Name: 0, dtype: object

# %%
df.nameOrig.value_counts()
# Out:
# C1902386530    3
# C363736674     3
# C545315117     3
# C724452879     3
# C1784010646    3
#               ..
# C98968405      1
# C720209255     1
# C1567523029    1
# C644777639     1
# C1280323807    1
# Name: nameOrig, Length: 6353307, dtype: int64

# %%
df.nameDest.value_counts()
# Out:
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
#               ...
# M1470027725      1
# M1330329251      1
# M1784358659      1
# M2081431099      1
# C2080388513      1
# Name: nameDest, Length: 2722362, dtype: int64

# %%
df.type.value_counts()
# Out:
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: type, dtype: int64

# %%
df.isFlaggedFraud.value_counts()
# Out:
# 0    6362604
# 1         16
# Name: isFlaggedFraud, dtype: int64

# %%
df.isFraud.value_counts()
# Out:
# 0    6354407
# 1       8213
# Name: isFraud, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

feature=['step','amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']

for i in feature:
    plt.xlabel(i)
    df[i].plot(kind='hist', bins=5, figsize=(12,6), facecolor='blue',edgecolor='black')
    plt.show()

# %%
##quantile used to return values at the given quantile over the requested axis
feature=['amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']

for i in feature:
    print(i)
    print(df[i].quantile(0.10))
    print(df[i].quantile(0.90))

    print('\n')
# Out:
# amount
# 4501.3
# 365423.30900000007
#
#
# oldbalanceOrg
# 0.0
# 1822508.289000007
#
#
# newbalanceOrig
# 0.0
# 1970344.7930000005
#
#
# oldbalanceDest
# 0.0
# 2914266.6690000016
#
#
# newbalanceDest
# 0.0
# 3194869.671000002

# %%
feature = ['amount','oldbalanceOrg','oldbalanceDest','newbalanceOrig','newbalanceDest']

for i in feature:
    lower = df[i].quantile(0.10)
    upper = df[i].quantile(0.90)
    df[i] = np.where (df[i] < lower, lower,df[i])
    df[i] = np.where (df[i] > upper, upper,df[i])
    print('feature: ',i)
    print('Inequality: ',df[i].skew())
    print('\n')
# Out:
# feature:  amount
# Inequality:  0.8046460444556197
#
#
# feature:  oldbalanceOrg
# Inequality:  2.249361299814406
#
#
# feature:  oldbalanceDest
# Inequality:  1.4173123924260833
#
#
# feature:  newbalanceOrig
# Inequality:  2.2262847493216786
#
#
# feature:  newbalanceDest
# Inequality:  1.3593024983493058

# %%
feature=['step','amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest']

for i in feature:
    plt.xlabel(i)
    df[i].plot(kind='hist', bins=5, figsize=(12,6), facecolor='blue',edgecolor='black')
    plt.show()

# %%
df.type
# Out:
# 0           PAYMENT
# 1           PAYMENT
# 2          TRANSFER
# 3          CASH_OUT
# 4           PAYMENT
#              ...
# 6362615    CASH_OUT
# 6362616    TRANSFER
# 6362617    CASH_OUT
# 6362618    TRANSFER
# 6362619    CASH_OUT
# Name: type, Length: 6362620, dtype: object

# %%
df.type.unique()
# Out:
# array(['PAYMENT', 'TRANSFER', 'CASH_OUT', 'DEBIT', 'CASH_IN'],
#       dtype=object)

# %%
payment = df.type.value_counts()
payment
# Out:
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: type, dtype: int64

# %%
## barh : is used to make a horizontal bar plot.
payment.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x= 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
##crosstab : is used to compute a simple cross tabulation of two (or more) factors.
CrosstabResult=pd.crosstab(index=df.type,columns=df.isFraud)
CrosstabResult
# Out:
# isFraud         0     1
# type
# CASH_IN   1399284     0
# CASH_OUT  2233384  4116
# DEBIT       41432     0
# PAYMENT   2151495     0
# TRANSFER   528812  4097

# %%
## Grouped bar chart between TYPE and ISFRAUD 
CrosstabResult.plot.bar(figsize=(7,4), rot=0)
# Out:
# <AxesSubplot:xlabel='type'>

# %%
CrosstabResult[1]
# Out:
# type
# CASH_IN        0
# CASH_OUT    4116
# DEBIT          0
# PAYMENT        0
# TRANSFER    4097
# Name: 1, dtype: int64

# %%
## Grouped bar chart between TYPE and ISFRAUD with maximizing
CrosstabResult[1].plot.bar(figsize=(7,4), rot=0)
# Out:
# <AxesSubplot:xlabel='type'>

# %%
## Changing ylimit to view isFraud values in grouped bar chart between TYPE and ISFRAUD
CrosstabResult.plot.bar(figsize=(7,4), rot=0)
plt.ylim([3000, 6500])
# Out:
# (3000.0, 6500.0)

# %%
CrosstabResult
# Out:
# isFraud         0     1
# type
# CASH_IN   1399284     0
# CASH_OUT  2233384  4116
# DEBIT       41432     0
# PAYMENT   2151495     0
# TRANSFER   528812  4097

# %%
cashout = 2233384+4116
cashout_fraud = 4116/(cashout) * 100
cashout_fraud
# Out:
# 0.18395530726256984

# %%
transfer= 528812+4097
transfer_fraud = 4097/(transfer) * 100
transfer_fraud
# Out:
# 0.7687991758442811

# %%
df.amount
# Out:
# 0            9839.640
# 1            4501.300
# 2            4501.300
# 3            4501.300
# 4           11668.140
#               ...
# 6362615    339682.130
# 6362616    365423.309
# 6362617    365423.309
# 6362618    365423.309
# 6362619    365423.309
# Name: amount, Length: 6362620, dtype: float64

# %%
## Will check the minimum and maximum range amount

plt.figure(figsize=(10,10))
sns.stripplot(y=df.amount)
# Out:
# <AxesSubplot:ylabel='amount'>

# %%
print('Minimum: ',df.amount.min())
print('Maximum: ',df.amount.max())
# Out:
# Minimum:  4501.3
# Maximum:  365423.30900000007

# %%
df.boxplot(column ='amount', by = 'isFraud')
# Out:
# <AxesSubplot:title={'center':'amount'}, xlabel='isFraud'>

# %%
df.isFlaggedFraud.value_counts()
# Out:
# 0    6362604
# 1         16
# Name: isFlaggedFraud, dtype: int64

# %%
flagged_fraud_records = df[(df.isFraud==1) & (df.isFlaggedFraud==1)]
flagged_fraud_records
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2736446   212  TRANSFER  365423.309   C728984460    1822508.289
# 3247297   250  TRANSFER  365423.309  C1100582606    1343002.080
# 3760288   279  TRANSFER  365423.309  C1035541766     536624.410
# 5563713   387  TRANSFER  365423.309   C908544136    1822508.289
# 5996407   425  TRANSFER  365423.309   C689608084    1822508.289
# 5996409   425  TRANSFER  365423.309   C452586515    1822508.289
# 6168499   554  TRANSFER  365423.309   C193696150    1822508.289
# 6205439   586  TRANSFER  353874.220  C1684585475     353874.220
# 6266413   617  TRANSFER  365423.309   C786455622    1822508.289
# 6281482   646  TRANSFER  365423.309    C19004745    1822508.289
# 6281484   646  TRANSFER  365423.309   C724693370    1822508.289
# 6296014   671  TRANSFER  365423.309   C917414431    1822508.289
# 6351225   702  TRANSFER  365423.309  C1892216157    1822508.289
# 6362460   730  TRANSFER  365423.309  C2140038573    1822508.289
# 6362462   730  TRANSFER  365423.309  C1869569059    1822508.289
# 6362584   741  TRANSFER  365423.309   C992223106    1822508.289
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2736446     1970344.793   C639921569             0.0             0.0        1
# 3247297     1343002.080  C1147517658             0.0             0.0        1
# 3760288      536624.410  C1100697970             0.0             0.0        1
# 5563713     1970344.793   C891140444             0.0             0.0        1
# 5996407     1970344.793  C1392803603             0.0             0.0        1
# 5996409     1970344.793  C1109166882             0.0             0.0        1
# 6168499     1970344.793   C484597480             0.0             0.0        1
# 6205439      353874.220  C1770418982             0.0             0.0        1
# 6266413     1970344.793   C661958277             0.0             0.0        1
# 6281482     1970344.793  C1806199534             0.0             0.0        1
# 6281484     1970344.793  C1909486199             0.0             0.0        1
# 6296014     1970344.793  C1082139865             0.0             0.0        1
# 6351225     1970344.793  C1308068787             0.0             0.0        1
# 6362460     1970344.793  C1395467927             0.0             0.0        1
# 6362462     1970344.793  C1861208726             0.0             0.0        1
# 6362584     1970344.793  C1366804249             0.0             0.0        1
#
#          isFlaggedFraud
# 2736446               1
# 3247297               1
# 3760288               1
# 5563713               1
# 5996407               1
# 5996409               1
# 6168499               1
# 6205439               1
# 6266413               1
# 6281482               1
# 6281484               1
# 6296014               1
# 6351225               1
# 6362460               1
# 6362462               1
# 6362584               1

# %%
flagged_fraud_records.shape
# Out:
# (16, 11)

# %%
total_fraud= df[df.isFraud ==1]
total_fraud = total_fraud.shape[0]
total_fraud
# Out:
# 8213

# %%
total_isflaggedFraud= flagged_fraud_records.shape[0]
total_isflaggedFraud
# Out:
# 16

# %%
flagged_percent = total_isflaggedFraud/total_fraud * 100
print('Flagged fraud percentage ',round(flagged_percent,3))

unflagged_percent= (total_fraud-total_isflaggedFraud)/total_fraud * 100
print('Flagged fraud incorrect percentage: ',round(unflagged_percent,3))
# Out:
# Flagged fraud percentage  0.195
# Flagged fraud incorrect percentage:  99.805

# %%
total_transactions = df.shape[0]

fraud_transaction = df[df.isFraud==1].shape[0]

fraud_percent= fraud_transaction/total_transactions * 100
fraud_percent
# Out:
# 0.12908204481801522

# %%
print('Total transactions: ',total_transactions)
print('Total fraud transactions happened: ',fraud_transaction)
print("Total fraud transaction percent : ",round(fraud_percent,2))
# Out:
# Total transactions:  6362620
# Total fraud transactions happened:  8213
# Total fraud transaction percent :  0.13

# %%
fraud_amount = df[df.isFraud==1]
fraud_amount = fraud_amount.sort_values(by=['amount'],ascending = False)
fraud_amount
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 5188057   367  CASH_OUT  365423.309  C1210833971     435867.160
# 5990227   416  CASH_OUT  365423.309  C2110305720    1822508.289
# 5990225   416  CASH_OUT  365423.309   C246726057    1822508.289
# 5990224   416  TRANSFER  365423.309   C298387535    1822508.289
# 5988262   415  CASH_OUT  365423.309  C2137951962    1675153.280
# ...       ...       ...         ...          ...            ...
# 6002113   428  CASH_OUT    4501.300  C1838531308       3037.670
# 6002112   428  TRANSFER    4501.300  C1408814433       3037.670
# 1796322   162  TRANSFER    4501.300  C1172437299        151.000
# 1796323   162  CASH_OUT    4501.300   C790340353        151.000
# 2           1  TRANSFER    4501.300  C1305486145        181.000
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 5188057           0.000   C363013236       186826.40      622693.550        1
# 5990227           0.000   C225008798       523626.59     3194869.671        1
# 5990225           0.000  C1786144514      2423749.18     3194869.671        1
# 5990224     1970344.793   C662194461            0.00           0.000        1
# 5988262           0.000   C309573869        12832.26     1687985.530        1
# ...                 ...          ...             ...             ...      ...
# 6002113           0.000   C505532836       800854.71      803892.380        1
# 6002112           0.000   C944070846            0.00           0.000        1
# 1796322           0.000   C315826176            0.00           0.000        1
# 1796323           0.000   C517676411       386163.34      386314.340        1
# 2                 0.000   C553264065            0.00           0.000        1
#
#          isFlaggedFraud
# 5188057               0
# 5990227               0
# 5990225               0
# 5990224               0
# 5988262               0
# ...                 ...
# 6002113               0
# 6002112               0
# 1796322               0
# 1796323               0
# 2                     0
#
# [8213 rows x 11 columns]

# %%
fraud_amount.amount.plot(kind='hist', bins=15, figsize=(12,6), facecolor='grey',edgecolor='black')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
fraudster= df.nameDest.value_counts()
fraudster
# Out:
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
#               ...
# M1470027725      1
# M1330329251      1
# M1784358659      1
# M2081431099      1
# C2080388513      1
# Name: nameDest, Length: 2722362, dtype: int64

# %%
fraudster[:10]
# Out:
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C451111351      99
# C1789550256     99
# C1360767589     98
# C1023714065     97
# Name: nameDest, dtype: int64

# %%
fraudster[:10].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15, 6))
sns.distplot(df['step'], bins=50)
# Out:
# C:\Users\Anika!!\AppData\Local\Temp\ipykernel_18632\395256865.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['step'], bins=50)
# <AxesSubplot:xlabel='step', ylabel='Density'>

# %%
corr = df.corr()# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap='Blues' ,fmt=".3f")
# Out:
# C:\Users\Anika!!\AppData\Local\Temp\ipykernel_18632\166179158.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()# plot the heatmap
# <AxesSubplot:>
